# %% [markdown]
# <a href="https://colab.research.google.com/github/TWOD22/DesafioTelecomX/blob/main/DesafioTelecomX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Extracción

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('/content/TelecomX_Data.json')

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df['customer'][0]
# Out:
# {'gender': 'Female',
#  'SeniorCitizen': 0,
#  'Partner': 'Yes',
#  'Dependents': 'Yes',
#  'tenure': 9}

# %%
df['internet'][0]
# Out:
# {'InternetService': 'DSL',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'Yes',
#  'DeviceProtection': 'No',
#  'TechSupport': 'Yes',
#  'StreamingTV': 'Yes',
#  'StreamingMovies': 'No'}

# %%
df['account'][0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %%
df_customer = pd.json_normalize(df['customer'])

# %%
df_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_phone = pd.json_normalize(df['phone'])
df_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_internet = pd.json_normalize(df['internet'])
df_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
df_account = pd.json_normalize(df['account'])
df_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %% [markdown]
# # 🔧 Transformación

# %% [markdown]
# Usamos df.drop para poder eliminar las columnas antiguas y ya junto a concat podemos unir las nuevas columnas ya utilizando normalize

# %%
df_normalized = pd.concat([df.drop(['customer', 'phone', 'internet', 'account'], axis=1), df_customer, df_phone, df_internet, df_account], axis=1)
df_normalized
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
unique_churn_values = df_normalized['Charges.Monthly'].unique()

print(unique_churn_values)
# Out:
# [65.6  59.9  73.9  ... 91.75 68.8  67.85]

# %%
df_normalized['Charges.Total'] = df_normalized['Charges.Total'].replace(r'^\s*$', np.nan, regex=True)
df_normalized['Charges.Total'] = df_normalized['Charges.Total'].astype(np.float64)

# %% [markdown]
# ## Columna de cuentas diarias

# %%
df_normalized['Charges.Daily'] = df_normalized['Charges.Monthly'] / 30

# %%
pd.set_option('display.max_columns', None)
display(df_normalized)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# ...

# %% [markdown]
# ## Estandarización y transformación de datos (opcional)

# %%
columnas_binarias = ['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']
df_normalized[columnas_binarias] = df_normalized[columnas_binarias].replace({'Yes': 1, 'No': 0})
# Out:
# /tmp/ipython-input-24-4141229956.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_normalized[columnas_binarias] = df_normalized[columnas_binarias].replace({'Yes': 1, 'No': 0})

# %%
df_normalized
# Out:
#       customerID Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO     0  Female              0        1           1       9
# 1     0003-MKNFE     0    Male              0        0           0       9
# 2     0004-TLHLJ     1    Male              0        0           0       4
# 3     0011-IGKFF     1    Male              1        1           0      13
# 4     0013-EXCHZ     1  Female              1        1           0       3
# ...          ...   ...     ...            ...      ...         ...     ...
# 7262  9987-LUTYD     0  Female              0        0           0      13
# 7263  9992-RRAMN     1    Male              0        1           0      22
# 7264  9992-UJOEL     0    Male              0        0           0       2
# 7265  9993-LHIEB     0    Male              0        1           1      67
# 7266  9995-HOTOH     0    Male              0        1           1      63
#
# ...

# %%
df_normalized = df_normalized.replace({'No internet service': 0, 'No phone service': 0})
df_normalized['Churn'] = df_normalized['Churn'].replace('', 0)
# Out:
# /tmp/ipython-input-26-504882145.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_normalized = df_normalized.replace({'No internet service': 0, 'No phone service': 0})
# /tmp/ipython-input-26-504882145.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_normalized['Churn'] = df_normalized['Churn'].replace('', 0)

# %%
for x in columnas_binarias:
  unique_values = df_normalized[x].unique()
  print(f"Unique values in '{x}': {unique_values}")
# Out:
# Unique values in 'Churn': [0 1]
# Unique values in 'Partner': [1 0]
# Unique values in 'Dependents': [1 0]
# Unique values in 'PhoneService': [1 0]
# Unique values in 'MultipleLines': [0 1]
# Unique values in 'OnlineSecurity': [0 1]
# Unique values in 'OnlineBackup': [1 0]
# Unique values in 'DeviceProtection': [0 1]
# Unique values in 'TechSupport': [1 0]
# Unique values in 'StreamingTV': [1 0]
# Unique values in 'StreamingMovies': [0 1]
# Unique values in 'PaperlessBilling': [1 0]

# %% [markdown]
# # 📊 Carga y análisis

# %%
df_normalized.describe()
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7267.000000    7267.000000  7267.000000  7267.000000  7267.000000
# mean      0.257190       0.162653     0.484106     0.300124    32.346498
# std       0.437115       0.369074     0.499782     0.458343    24.571773
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  \
# count   7267.000000    7267.000000     7267.000000   7267.000000
# mean       0.902711       0.421770        0.285950      0.344571
# std        0.296371       0.493876        0.451897      0.475261
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_normalized['Churn'].value_counts()
# Out:
# Churn
# 0    5398
# 1    1869
# Name: count, dtype: int64

# %%
churn_cuenta = df_normalized['Churn'].value_counts()

# %%
plt.figure(figsize=(8,4))
plt.bar([0, 1], churn_cuenta, color=['red', 'blue'])
plt.xticks([0, 1], ['Se dieron de baja','Permanecen'])
plt.title('Distribución de Clientes según Evasión (Churn)')
plt.xlabel('Estado de Columna Churn')
plt.ylabel('Cantidad de Clientes')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Análisis Descriptivo

# %%
numeric_columns = df_normalized.select_dtypes(include=[np.number]).columns

describe_df = df_normalized[numeric_columns].describe().T
describe_df['median'] = df_normalized[numeric_columns].median()
describe_df = describe_df.round(2)


describe_df
# Out:
#                    count     mean      std    min     25%      50%      75%  \
# Churn             7267.0     0.26     0.44   0.00    0.00     0.00     1.00
# SeniorCitizen     7267.0     0.16     0.37   0.00    0.00     0.00     0.00
# Partner           7267.0     0.48     0.50   0.00    0.00     0.00     1.00
# Dependents        7267.0     0.30     0.46   0.00    0.00     0.00     1.00
# tenure            7267.0    32.35    24.57   0.00    9.00    29.00    55.00
# PhoneService      7267.0     0.90     0.30   0.00    1.00     1.00     1.00
# MultipleLines     7267.0     0.42     0.49   0.00    0.00     0.00     1.00
# OnlineSecurity    7267.0     0.29     0.45   0.00    0.00     0.00     1.00
# OnlineBackup      7267.0     0.34     0.48   0.00    0.00     0.00     1.00
# DeviceProtection  7267.0     0.34     0.47   0.00    0.00     0.00     1.00
# TechSupport       7267.0     0.29     0.45   0.00    0.00     0.00     1.00
# ...

# %% [markdown]
# ## Recuento de evasión por variables categóricas

# %% [markdown]
# ### Género

# %%
tabla_genero = pd.crosstab(df_normalized['gender'], df_normalized['Churn'], normalize='index') * 100
tabla_genero.columns = ['Permanecen (%)', 'Se fueron (%)']
tabla_genero.round(2)
# Out:
#         Permanecen (%)  Se fueron (%)
# gender
# Female           73.86          26.14
# Male             74.69          25.31

# %%
tabla_genero = pd.crosstab(df_normalized['gender'], df_normalized['Churn'])
porcentaje_genero = tabla_genero.div(tabla_genero.sum(axis=1), axis=0)


colores = ['blue', 'red']
etiquetas = ['Permanecen', 'Se dieron de baja']


ax = porcentaje_genero.plot(kind='bar', stacked=False, color=colores, figsize=(8,5))


plt.title('Proporción de Evasión por Género')
plt.xlabel('Género')
plt.ylabel('Proporción')
plt.xticks(rotation=0)
plt.legend(title='Estado del Cliente', labels=etiquetas, loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Adultos Mayores

# %%
tabla_senior = pd.crosstab(df_normalized['SeniorCitizen'], df_normalized['Churn'])

tabla_senior.columns = ['Permanecen (%)', 'Se fueron (%)']
porcentaje_senior = tabla_senior.div(tabla_senior.sum(axis=1), axis=0).round(2)*100


porcentaje_senior
# Out:
#                Permanecen (%)  Se fueron (%)
# SeniorCitizen
# 0                        77.0           23.0
# 1                        60.0           40.0

# %%
porcentaje_senior.plot(kind='bar', stacked=False, color=['steelblue', 'salmon'], figsize=(8,5))

plt.title('Porcentaje de Evasión por Adultos Mayores')
plt.xlabel('¿Es Adulto Mayor?')
plt.ylabel('Porcentaje (%)')
plt.xticks(ticks=[0, 1], labels=['No', 'Sí'], rotation=0)
plt.legend(title='¿Se dio de baja?', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tipo de contrato

# %% [markdown]
# ####TABLA

# %%
tabla_contrato = pd.crosstab(df_normalized['Contract'], df_normalized['Churn'])


tabla_contrato.columns = ['Permanecen (%)', 'Se fueron (%)']
porcentaje_contrato = tabla_contrato.div(tabla_contrato.sum(axis=1), axis=0).round(3) * 100

print(porcentaje_contrato)
# Out:
#                 Permanecen (%)  Se fueron (%)
# Contract
# Month-to-month            58.7           41.3
# One year                  89.1           10.9
# Two year                  97.2            2.8

# %% [markdown]
# ####GRAFICO

# %%
ax = porcentaje_contrato.plot(kind='bar', stacked=False, color=['blue', 'red'], figsize=(8, 5))

plt.title('Proporción de Evasión por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Proporción (%)')
plt.xticks(rotation=0)
plt.legend(title='¿Se dio de baja?', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### METODO DE PAGO

# %%
tabla_pago = pd.crosstab(df_normalized['PaymentMethod'], df_normalized['Churn'])
tabla_pago.columns = ['Permanecen (%)', 'Se fueron (%)']

porcentaje_pago = tabla_pago.div(tabla_pago.sum(axis=1), axis=0).round(3) * 100

print(porcentaje_pago)
# Out:
#                            Permanecen (%)  Se fueron (%)
# PaymentMethod
# Bank transfer (automatic)            83.8           16.2
# Credit card (automatic)              85.2           14.8
# Electronic check                     56.2           43.8
# Mailed check                         81.5           18.5

# %%
porcentaje_pago.plot(kind='bar', stacked=False, color=['blue', 'red'], figsize=(10,6))

plt.title('Proporción de Evasión por Método de Pago')
plt.xlabel('Método de Pago')
plt.ylabel('Proporción')
plt.xticks(rotation=45, ha='right')
plt.legend(['No se dio de baja', 'Se dio de baja'], title='¿Churn?', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📄Informe final
